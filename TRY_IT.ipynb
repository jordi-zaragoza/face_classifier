# %% [markdown]
# # Here you can try the classifier

# %%
from face_classify import classifier
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# Loaded model:  model_eye_right
# Loaded model:  model_sunglasses
# Loaded model:  model_blurry
# Loaded model:  model_profile

# %%
classifier(name='face1', image_or_path='face_classify/data/open_test/closed1.jpg', crop_face = True)
# Out:
# Closed eyes:
# {'name': 'face1',
#  'blurry': 0.0,
#  'profile': 0.0,
#  'sunglasses': 0.0,
#  'eyes': (0.0, 0.0)}

# %%
classifier(name='face2', image_or_path='face_classify/data/open_test/open6.jpg', crop_face = True)
# Out:
# Open eyes:
# {'name': 'face2',
#  'blurry': 0.0,
#  'profile': 0.0,
#  'sunglasses': 0.0,
#  'eyes': (0.935, 0.757)}

# %%
classifier(name='face3', image_or_path='face_classify/data/profile_test/profile2.jpg', crop_face = True)
# Out:
# Profile image
# {'name': 'face3',
#  'blurry': 0.001,
#  'profile': 1.0,
#  'sunglasses': None,
#  'eyes': None}

# %%
classifier(name='face4', image_or_path='face_classify/data/sunglasses_test/sunglass1.jpg', crop_face = True)
# Out:
# Sunglasses image
# {'name': 'face4',
#  'blurry': 0.0,
#  'profile': 0.0,
#  'sunglasses': 0.716,
#  'eyes': None}

# %%
classifier(name='face5', image_or_path='face_classify/data/blurry_test/blurry2.jpg', crop_face = False)
# Out:
# Sunglasses image
# {'name': 'face5',
#  'blurry': 0.011,
#  'profile': 0.065,
#  'sunglasses': 1.0,
#  'eyes': None}
